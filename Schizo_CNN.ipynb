# %%
import os
import re
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
from matplotlib import pyplot as plt
from sznet import build_sz_net
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from keras.optimizers import Adam
from keras.callbacks import  EarlyStopping, CSVLogger, TensorBoard
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import roc_curve, auc

# %%
SUBJECT_DATA_FILE_REGEX = re.compile(r'(\d{1,2}).csv')
METADATA_DIR_PATH = './archive'
DATA_DIR_RAW_PATHS = (METADATA_DIR_PATH, './archive2')
STRIPPED_DATA_PATH = './stripped'

# %%
model = build_sz_net((256, 5, 1))
model.summary()
# Out:
# Model: "sznet"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 256, 5, 1)]       0
#
#  conv2d_32 (Conv2D)          (None, 248, 5, 16)        160
#
#  batch_normalization_28 (Ba  (None, 248, 5, 16)        64
#  tchNormalization)
#
#  activation_32 (Activation)  (None, 248, 5, 16)        0
#
#  dropout_20 (Dropout)        (None, 248, 5, 16)        0
#
#  conv2d_33 (Conv2D)          (None, 240, 5, 16)        2320
#
#  batch_normalization_29 (Ba  (None, 240, 5, 16)        64
#  tchNormalization)
#
#  activation_33 (Activation)  (None, 240, 5, 16)        0
#
#  max_pooling2d_12 (MaxPooli  (None, 120, 5, 16)        0
#  ng2D)
#
#  conv2d_34 (Conv2D)          (None, 112, 5, 32)        4640
#
#  batch_normalization_30 (Ba  (None, 112, 5, 32)        128
#  tchNormalization)
#
#  activation_34 (Activation)  (None, 112, 5, 32)        0
#
#  dropout_21 (Dropout)        (None, 112, 5, 32)        0
#
#  conv2d_35 (Conv2D)          (None, 104, 5, 32)        9248
#
#  batch_normalization_31 (Ba  (None, 104, 5, 32)        128
#  tchNormalization)
#
#  activation_35 (Activation)  (None, 104, 5, 32)        0
#
#  max_pooling2d_13 (MaxPooli  (None, 52, 5, 32)         0
#  ng2D)
#
#  conv2d_36 (Conv2D)          (None, 44, 5, 64)         18496
#
#  batch_normalization_32 (Ba  (None, 44, 5, 64)         256
#  tchNormalization)
#
#  activation_36 (Activation)  (None, 44, 5, 64)         0
#
#  dropout_22 (Dropout)        (None, 44, 5, 64)         0
#
#  conv2d_37 (Conv2D)          (None, 36, 5, 64)         36928
#
#  batch_normalization_33 (Ba  (None, 36, 5, 64)         256
#  tchNormalization)
#
#  activation_37 (Activation)  (None, 36, 5, 64)         0
#
#  max_pooling2d_14 (MaxPooli  (None, 18, 5, 64)         0
#  ng2D)
#
#  conv2d_38 (Conv2D)          (None, 18, 3, 32)         6176
#
#  batch_normalization_34 (Ba  (None, 18, 3, 32)         128
#  tchNormalization)
#
#  activation_38 (Activation)  (None, 18, 3, 32)         0
#
#  conv2d_39 (Conv2D)          (None, 16, 1, 32)         9248
#
#  activation_39 (Activation)  (None, 16, 1, 32)         0
#
#  dropout_23 (Dropout)        (None, 16, 1, 32)         0
#
#  flatten_4 (Flatten)         (None, 512)               0
#
#  dense_12 (Dense)            (None, 512)               262656
#
#  dropout_24 (Dropout)        (None, 512)               0
#
#  dense_13 (Dense)            (None, 128)               65664
#
#  dense_14 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 416689 (1.59 MB)
# Trainable params: 416177 (1.59 MB)
# Non-trainable params: 512 (2.00 KB)
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %% [markdown]
# data format:
#
# ```
# for each subject (~80):
#     for each trial (~100):
#         vec = [~3000 x 74 x 3] (time samples x electrodes+stuff x condition)
#         only_second_condition = [~3000 x 74] (time samples x electrodes+stuff)
#         only_needed = [~3000 x 5] (pick only 5 needed electrodes: Fz, FCz, Cz, CPz, Pz)
#         only_needed_in_shortened_time = [512 x 5] (pick time from -100ms to 400ms)
#         only_needed_subsampled = [256 x 5] (subsample signal)
#         add only_needed_subsampled to the X dataset
#         add subject label to Y dataset (0 = healty, 1 = SZ)
# ```

# %%
def build_stripped_dataset(archive_paths=DATA_DIR_RAW_PATHS, target_path=STRIPPED_DATA_PATH, metadata_dir=METADATA_DIR_PATH,
        condition=2, time_min=-100., time_max=400., electrodes=('Fz', 'FCz', 'Cz', 'CPz', 'Pz'),
        subsample=True, time_file_filename='time.csv', column_labels_filename='columnLabels.csv'):
    time_df = pd.read_csv(os.path.join(metadata_dir, time_file_filename))
    column_labels_df = pd.read_csv(os.path.join(metadata_dir, column_labels_filename))
    time_range = time_df[(time_df[' time_ms'] > time_min) & (time_df[' time_ms'] < time_max)]
    min_sample = int(time_range.iloc[0]['sample'])
    max_sample = int(time_range.iloc[-1]['sample'])

    if subsample and (max_sample - min_sample + 1) % 2 == 1:
        max_sample += 1

    try:
        os.mkdir(target_path)
    except FileExistsError:
        pass

    for dir in archive_paths:
        for file_name in tqdm(os.listdir(dir)):
            if SUBJECT_DATA_FILE_REGEX.match(file_name):
                path = os.path.join(dir, file_name, file_name)
                data = pd.read_csv(path)
                data.columns = column_labels_df.columns
                stripped_data = data[(data['condition'] == condition) & (data['sample'] >= min_sample) & (data['sample'] <= max_sample)]
                stripped_data = stripped_data[['trial', 'sample', *electrodes]]
                if subsample:
                    stripped_data_np = stripped_data.to_numpy()
                    subsampled = (stripped_data_np[::2, 1:] + stripped_data_np[1::2, 1:]) / 2
                    subsampled = np.hstack((stripped_data_np[::2, 0].reshape(-1, 1), subsampled))
                    stripped_data = pd.DataFrame(subsampled, columns=stripped_data.columns)
                stripped_data.to_csv(os.path.join(target_path, file_name), index=False)
    
    with open(os.path.join(target_path, 'info.csv'), 'w') as f:
        f.write(f'contidion,time_min,time_max,subsampled\n')
        f.write(f'{condition},{time_min},{time_max},{subsample}\n')

# build_stripped_dataset()

# %%
labels = pd.read_csv('./archive/columnLabels.csv')

# %%
csv1 = pd.read_csv('./archive2/44.csv/44.csv')

# %%
csv1.columns = labels.columns

# %%
csv1_prepr = pd.read_csv('./stripped/44.csv')

# %%
csv1.describe()
# Out:
#         subject          trial     condition         sample            Fp1  \
# count  887807.0  887807.000000  887807.00000  887807.000000  887807.000000
# mean       44.0      49.242259       1.98270    1536.501730      -0.058368
# std         0.0      28.159891       0.81702     886.809468       8.598968
# min        44.0       1.000000       1.00000       1.000000     -61.325900
# 25%        44.0      25.000000       1.00000     769.000000      -5.595150
# 50%        44.0      49.000000       2.00000    1537.000000      -0.056800
# 75%        44.0      73.000000       3.00000    2304.500000       5.434600
# max        44.0      99.000000       3.00000    3072.000000      49.153300
#
#                  AF7            AF3             F1             F3  \
# count  887807.000000  887807.000000  887807.000000  887807.000000
# mean        0.023549       0.208894      -0.094736       0.145352
# std         7.269081       8.717609       9.958434       9.605836
# min       -38.980600     -61.765400     -66.787200     -48.194500
# 25%        -4.653000      -5.454900      -6.540700      -6.115500
# 50%        -0.049400       0.238700      -0.125400       0.135200
# 75%         4.619500       5.887300       6.228800       6.371700
# max        39.376400      46.914600      57.099000      50.761600
#
#                   F5  ...            P10            PO8            PO4  \
# count  887807.000000  ...  887807.000000  887807.000000  887807.000000
# mean       -0.038817  ...       0.198712      -0.113832      -0.077242
# std         8.966533  ...       7.920635       9.356017      10.917907
# min       -66.109600  ...     -43.217800     -48.237900     -66.046900
# 25%        -5.772100  ...      -4.706800      -6.225600      -7.153400
# 50%        -0.041300  ...       0.120200      -0.114500      -0.065200
# 75%         5.628900  ...       5.044200       5.985800       7.041600
# max        47.742500  ...      42.893100      65.850900      63.326500
#
#                   O2           VEOa           VEOb           HEOL  \
# count  887807.000000  887807.000000  887807.000000  887807.000000
# mean       -0.076054       0.919652       0.263858      -0.549402
# std        10.977510      27.933819      21.140853      25.688777
# min       -52.314200    -205.132900    -158.637500    -194.041000
# 25%        -7.295300     -11.794700      -8.070050      -8.379500
# 50%         0.005700       0.630500       0.103600       0.273300
# 75%         7.146200      12.182100       8.226000       8.777300
# max        54.629200     334.048600     201.942100     165.401800
#
#                 HEOR           Nose           TP10
# count  887807.000000  887807.000000  887807.000000
# mean        0.403265       0.131561       0.263778
# std        23.737666      15.922234      10.372241
# min      -160.937800    -160.739400     -77.765400
# 25%        -9.921800      -7.278200      -6.224950
# 50%         0.177400      -0.174400       0.069900
# 75%        10.221950       6.891300       6.578100
# max       353.697400     155.707400      87.058000
#
# [8 rows x 74 columns]

# %%
sns.lineplot(csv1[(csv1['condition'] == 2)][['sample', 'Cz']].groupby(['sample']).mean(), x='sample', y='Cz')
# Out:
# <Axes: xlabel='sample', ylabel='Cz'>

# %%
csv1_prepr.describe()
# Out:
#               trial        sample            Fz           FCz            Cz  \
# count  24576.000000  24576.000000  24576.000000  24576.000000  24576.000000
# mean      49.697917   1690.500000     -0.239756     -0.348574     -0.606235
# std       28.016979    147.803548      8.743111      9.509758      9.939041
# min        1.000000   1435.500000    -39.784550    -45.813850    -45.442250
# 25%       25.750000   1563.000000     -5.948550     -6.574825     -6.977462
# 50%       49.500000   1690.500000     -0.211975     -0.288175     -0.379725
# 75%       73.250000   1818.000000      5.518375      5.856025      5.845838
# max       98.000000   1945.500000     33.199500     35.333450     40.110450
#
#                 CPz            Pz
# count  24576.000000  24576.000000
# mean      -0.528728     -0.501137
# std        9.903317      9.711517
# min      -44.803800    -44.969900
# 25%       -6.920900     -7.007187
# 50%       -0.374650     -0.371225
# 75%        5.877625      5.913300
# max       40.239100     33.260600

# %%
sns.lineplot(csv1_prepr[['sample', 'Cz']].groupby(['sample']).mean(), x='sample', y='Cz')
# Out:
# <Axes: xlabel='sample', ylabel='Cz'>

# %%
demographic = pd.read_csv(os.path.join(METADATA_DIR_PATH, 'demographic.csv')).set_index('subject')
demographic.loc[44][' group']
# Out:
# 1

# %%
def load_data(metadata_dir=METADATA_DIR_PATH, data_dir=STRIPPED_DATA_PATH) -> tuple[np.ndarray, np.ndarray, np.ndarray]:
    demographic = pd.read_csv(os.path.join(metadata_dir, 'demographic.csv')).set_index('subject')
    X, Y, idxs = [], [], []

    filenames = []
    for file_name in os.listdir(data_dir):
        if match := SUBJECT_DATA_FILE_REGEX.match(file_name):
            subject_id = int(match.group(1))
            filenames.append((file_name, subject_id))

    np.random.shuffle(filenames)

    for file_name, subject_id in filenames:
        # 0 -> healthy, 1 -> SZ
        health_class = demographic.loc[subject_id][' group']

        data = pd.read_csv(os.path.join(data_dir, file_name))
        trials = data['trial'].unique()

        for trial in trials:
            trial_data = data[data['trial'] == trial]
            X.append(trial_data.drop(['trial', 'sample'], axis=1).to_numpy())
        
        Y.extend([health_class] * len(trials))
        idxs.extend([subject_id] * len(trials))

    return np.stack(X, axis=0), np.stack(Y, axis=0), np.stack(idxs, axis=0)

# %%
x, y, idxs = load_data()

# %%
def preprocess(X: np.ndarray, idxs: np.ndarray, standardize=False) -> np.ndarray:
    min_x = np.min(X, axis=1).reshape((X.shape[0], 1, -1))
    max_x = np.max(X, axis=1).reshape((X.shape[0], 1, -1))
    scaled = (X - min_x) / (max_x - min_x)
    standardized = scaled

    if standardize:
        # per subject standarization
        # for idx in np.unique(idxs):
        #     subject_data = standardized[np.where(idxs == idx)]
        #     standardized[np.where(idxs == idx)] = (subject_data - np.mean(subject_data, axis=0)) / np.std(subject_data, axis=0)
        standardized = (standardized - np.mean(standardized, axis=1)[:,np.newaxis,:]) / np.std(standardized, axis=1)[:,np.newaxis,:]

    return standardized

# %%
x, y, idxs = load_data()

# %%
x.shape
# Out:
# (7631, 256, 5)

# %%
x_preprocessed = preprocess(x, idxs, standardize=True)

# %%
fig, axs = plt.subplots(1, 2, figsize=(11, 5))
axs[0].plot(np.arange(256), x[0, :, 0])
axs[1].plot(np.arange(256), x_preprocessed[0, :, 0])
axs[0].set_title("before normalization")
axs[1].set_title("after normalization")
plt.show()

# %%
def build_tfds(x: np.ndarray, y: np.ndarray, batch_size: int):
    tfds = tf.data.Dataset.from_tensor_slices((x, y))
    tfds = tfds.shuffle(x.shape[0])
    tfds = tfds.batch(batch_size)
    tfds = tfds.prefetch(tf.data.experimental.AUTOTUNE)
    return tfds

# %%
def load_and_preprocess(test_size=0.1, val_size=0.15, standardize=False):
    x, y, idxs = load_data()
    x = preprocess(x, idxs, standardize=standardize)
    train_idxs, test_idxs = train_test_split(np.unique(idxs), test_size=test_size)
    if val_size is not None:
        train_idxs, val_idxs = train_test_split(train_idxs, test_size=val_size)
    train_idxs0 = train_idxs
    train_idxs = np.isin(idxs, train_idxs)
    test_idxs = np.isin(idxs, test_idxs)
    if val_size is not None:
        val_idxs = np.isin(idxs, val_idxs)
        val_x = x[val_idxs]
        val_y = y[val_idxs]
    else:
        val_x, val_y = None, None
    train_x, test_x = x[train_idxs], x[test_idxs]
    train_y, test_y = y[train_idxs], y[test_idxs]
    return x, y, idxs, train_idxs0, train_idxs, (train_x, train_y), (val_x, val_y), (test_x, test_y)

def load_and_preprocess_test_val_same_amount_of_sz_hc(test_size=0.1, val_size=0.15, standardize=False):
    x, y, idxs = load_data()
    x = preprocess(x, idxs, standardize=standardize)

    all_idxs = np.unique(idxs)
    healthy_idxs = []
    sz_idxs = []
    for idx in all_idxs:
        if y[np.where(idxs == idx)][0] == 0:
            healthy_idxs.append(idx)
        else:
            sz_idxs.append(idx)

    sz_fraq = len(sz_idxs) / len(all_idxs)
    h_fraq = 1 - sz_fraq

    train_idxs_hc, test_idxs_hc = train_test_split(healthy_idxs, test_size=test_size * h_fraq)
    train_idxs_hc, val_idxs_hc = train_test_split(train_idxs_hc, test_size=val_size * h_fraq)

    train_idxs_sz, test_idxs_sz = train_test_split(sz_idxs, test_size=test_size * sz_fraq)
    train_idxs_sz, val_idxs_sz = train_test_split(train_idxs_sz, test_size=val_size * sz_fraq)

    train_idxs = [*train_idxs_hc, *train_idxs_sz]
    test_idxs = [*test_idxs_hc, *test_idxs_sz]
    val_idxs = [*val_idxs_hc, *val_idxs_sz]

    train_idxs0 = train_idxs
    train_idxs = np.isin(idxs, train_idxs)
    test_idxs = np.isin(idxs, test_idxs)
    if val_size is not None:
        val_idxs = np.isin(idxs, val_idxs)
        val_x = x[val_idxs]
        val_y = y[val_idxs]
    else:
        val_x, val_y = None, None
    train_x, test_x = x[train_idxs], x[test_idxs]
    train_y, test_y = y[train_idxs], y[test_idxs]
    return x, y, idxs, train_idxs0, train_idxs, (train_x, train_y), (val_x, val_y), (test_x, test_y)

# %%
def train_sznet(train: tuple[np.ndarray, np.ndarray], val: tuple[np.ndarray, np.ndarray],
                batch_size=4, epochs=100, learning_rate=1e-4, model_path="model_v1.h5", initial_model=None):
    train_x = train[0]
    if initial_model is None:
        model = build_sz_net((train_x.shape[1], train_x.shape[2], 1), dropout=0.25, dense_dropout=0.5, l2_regularization_coef=1e-4)
        model.compile(loss=tf.keras.losses.BinaryCrossentropy(from_logits=False), optimizer=Adam(learning_rate), metrics=['accuracy'])
    else:
        model = initial_model
    callbacks = [
        # ModelCheckpoint(model_path, verbose=1, save_best_only=True),
        EarlyStopping(monitor="val_loss", patience=20, restore_best_weights=False, start_from_epoch=60),
        CSVLogger(f'{model_path}.log.csv'),
        TensorBoard(
            f'{model_path}.log.tfboard',
            update_freq='epoch'
        )
    ]
    train_tfds = build_tfds(*train, batch_size)
    vald_tfds = build_tfds(*val, batch_size)

    return model.fit(train_tfds, validation_data=vald_tfds, epochs=epochs, callbacks=callbacks)

# %%
xx, yy, idxs, tidx0, tidx1, train, val, test = load_and_preprocess_test_val_same_amount_of_sz_hc(test_size=0.1, val_size=0.1, standardize=False)

# %%
res = train_sznet(train, val, learning_rate=1e-4, batch_size=8)
# Out:
# Epoch 1/100
# 2024-01-10 15:48:47.156601: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insznet/dropout_15/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 835/835 [==============================] - 12s 12ms/step - loss: 0.7825 - accuracy: 0.5881 - val_loss: 0.7643 - val_accuracy: 0.6059
# Epoch 2/100
# 835/835 [==============================] - 11s 13ms/step - loss: 0.7653 - accuracy: 0.6041 - val_loss: 0.7541 - val_accuracy: 0.6081
# Epoch 3/100
# 835/835 [==============================] - 11s 13ms/step - loss: 0.7611 - accuracy: 0.6078 - val_loss: 0.7507 - val_accuracy: 0.6123
# Epoch 4/100
# 835/835 [==============================] - 11s 13ms/step - loss: 0.7566 - accuracy: 0.6095 - val_loss: 0.7483 - val_accuracy: 0.6102
# Epoch 5/100
# 835/835 [==============================] - 10s 12ms/step - loss: 0.7537 - accuracy: 0.6117 - val_loss: 0.7373 - val_accuracy: 0.6165
# Epoch 6/100
# 835/835 [==============================] - 10s 12ms/step - loss: 0.7487 - accuracy: 0.6184 - val_loss: 0.7345 - val_accuracy: 0.6102
# Epoch 7/100
# 835/835 [==============================] - 10s 12ms/step - loss: 0.7459 - accuracy: 0.6153 - val_loss: 0.7283 - val_accuracy: 0.6081
# Epoch 8/100
# 835/835 [==============================] - 9s 11ms/step - loss: 0.7416 - accuracy: 0.6171 - val_loss: 0.7255 - val_accuracy: 0.6038
# Epoch 9/100
# 835/835 [==============================] - 9s 10ms/step - loss: 0.7362 - accuracy: 0.6180 - val_loss: 0.7216 - val_accuracy: 0.6123
# Epoch 10/100
# 835/835 [==============================] - 8s 9ms/step - loss: 0.7300 - accuracy: 0.6208 - val_loss: 0.7137 - val_accuracy: 0.5996
# Epoch 11/100
# 835/835 [==============================] - 10s 12ms/step - loss: 0.7281 - accuracy: 0.6279 - val_loss: 0.7154 - val_accuracy: 0.6229
# Epoch 12/100
# 835/835 [==============================] - 9s 10ms/step - loss: 0.7264 - accuracy: 0.6283 - val_loss: 0.7389 - val_accuracy: 0.6102
# Epoch 13/100
# 835/835 [==============================] - 6s 8ms/step - loss: 0.7210 - accuracy: 0.6328 - val_loss: 0.7366 - val_accuracy: 0.5975
# Epoch 14/100
# 835/835 [==============================] - 9s 11ms/step - loss: 0.7148 - accuracy: 0.6276 - val_loss: 0.7177 - val_accuracy: 0.5996
# Epoch 15/100
# 835/835 [==============================] - 9s 11ms/step - loss: 0.7099 - accuracy: 0.6319 - val_loss: 0.7287 - val_accuracy: 0.5614
# Epoch 16/100
# 835/835 [==============================] - 10s 12ms/step - loss: 0.6997 - accuracy: 0.6454 - val_loss: 0.7196 - val_accuracy: 0.5657
# Epoch 17/100
# 835/835 [==============================] - 11s 13ms/step - loss: 0.6931 - accuracy: 0.6436 - val_loss: 0.7377 - val_accuracy: 0.5763
# Epoch 18/100
# 835/835 [==============================] - 11s 13ms/step - loss: 0.6909 - accuracy: 0.6479 - val_loss: 0.7212 - val_accuracy: 0.5932
# Epoch 19/100
# 835/835 [==============================] - 9s 11ms/step - loss: 0.6848 - accuracy: 0.6559 - val_loss: 0.7588 - val_accuracy: 0.5572
# Epoch 20/100
# 835/835 [==============================] - 11s 13ms/step - loss: 0.6776 - accuracy: 0.6647 - val_loss: 0.7453 - val_accuracy: 0.5890
# Epoch 21/100
# 835/835 [==============================] - 11s 13ms/step - loss: 0.6696 - accuracy: 0.6701 - val_loss: 0.7643 - val_accuracy: 0.5466
# Epoch 22/100
# 835/835 [==============================] - 11s 13ms/step - loss: 0.6654 - accuracy: 0.6719 - val_loss: 0.7559 - val_accuracy: 0.5530
# Epoch 23/100
# 835/835 [==============================] - 11s 13ms/step - loss: 0.6571 - accuracy: 0.6725 - val_loss: 0.7419 - val_accuracy: 0.5657
# Epoch 24/100
# 835/835 [==============================] - 10s 12ms/step - loss: 0.6465 - accuracy: 0.6893 - val_loss: 0.7721 - val_accuracy: 0.5890
# Epoch 25/100
# 835/835 [==============================] - 11s 13ms/step - loss: 0.6367 - accuracy: 0.6950 - val_loss: 0.7719 - val_accuracy: 0.5530
# Epoch 26/100
# 835/835 [==============================] - 10s 12ms/step - loss: 0.6326 - accuracy: 0.6953 - val_loss: 0.7514 - val_accuracy: 0.5826
# Epoch 27/100
# 835/835 [==============================] - 10s 12ms/step - loss: 0.6272 - accuracy: 0.7013 - val_loss: 0.8725 - val_accuracy: 0.5572
# Epoch 28/100
# 835/835 [==============================] - 11s 13ms/step - loss: 0.6148 - accuracy: 0.7089 - val_loss: 0.8076 - val_accuracy: 0.5742
# Epoch 29/100
# 835/835 [==============================] - 10s 12ms/step - loss: 0.6151 - accuracy: 0.7131 - val_loss: 0.7869 - val_accuracy: 0.6123
# Epoch 30/100
# 835/835 [==============================] - 9s 10ms/step - loss: 0.6039 - accuracy: 0.7203 - val_loss: 0.7731 - val_accuracy: 0.5869
# Epoch 31/100
# 835/835 [==============================] - 9s 11ms/step - loss: 0.6028 - accuracy: 0.7200 - val_loss: 0.8100 - val_accuracy: 0.6059
# Epoch 32/100
# 835/835 [==============================] - 10s 12ms/step - loss: 0.5980 - accuracy: 0.7293 - val_loss: 0.7946 - val_accuracy: 0.5996
# Epoch 33/100
# 835/835 [==============================] - 10s 12ms/step - loss: 0.5806 - accuracy: 0.7372 - val_loss: 0.8216 - val_accuracy: 0.5953
# Epoch 34/100
# 835/835 [==============================] - 10s 12ms/step - loss: 0.5725 - accuracy: 0.7429 - val_loss: 0.8104 - val_accuracy: 0.5869
# Epoch 35/100
# 835/835 [==============================] - 9s 11ms/step - loss: 0.5671 - accuracy: 0.7421 - val_loss: 0.8465 - val_accuracy: 0.5826
# Epoch 36/100
# 835/835 [==============================] - 9s 11ms/step - loss: 0.5567 - accuracy: 0.7507 - val_loss: 0.8400 - val_accuracy: 0.5847
# Epoch 37/100
# 835/835 [==============================] - 10s 12ms/step - loss: 0.5456 - accuracy: 0.7619 - val_loss: 0.8820 - val_accuracy: 0.5614
# Epoch 38/100
# 835/835 [==============================] - 9s 11ms/step - loss: 0.5459 - accuracy: 0.7610 - val_loss: 0.8737 - val_accuracy: 0.5869
# Epoch 39/100
# 835/835 [==============================] - 10s 12ms/step - loss: 0.5307 - accuracy: 0.7725 - val_loss: 0.8665 - val_accuracy: 0.5911
# Epoch 40/100
# 835/835 [==============================] - 10s 12ms/step - loss: 0.5322 - accuracy: 0.7688 - val_loss: 0.8562 - val_accuracy: 0.5847
# Epoch 41/100
# 835/835 [==============================] - 10s 12ms/step - loss: 0.5174 - accuracy: 0.7806 - val_loss: 0.8816 - val_accuracy: 0.6059
# Epoch 42/100
# 835/835 [==============================] - 10s 12ms/step - loss: 0.5154 - accuracy: 0.7821 - val_loss: 0.8720 - val_accuracy: 0.6017
# Epoch 43/100
# 835/835 [==============================] - 10s 12ms/step - loss: 0.4987 - accuracy: 0.7950 - val_loss: 0.9617 - val_accuracy: 0.5890
# Epoch 44/100
# 835/835 [==============================] - 10s 12ms/step - loss: 0.4940 - accuracy: 0.7969 - val_loss: 0.8940 - val_accuracy: 0.5826
# Epoch 45/100
# 835/835 [==============================] - 10s 12ms/step - loss: 0.4999 - accuracy: 0.7954 - val_loss: 0.9658 - val_accuracy: 0.5826
# Epoch 46/100
# 835/835 [==============================] - 10s 12ms/step - loss: 0.4794 - accuracy: 0.8089 - val_loss: 0.8901 - val_accuracy: 0.5953
# Epoch 47/100
# 835/835 [==============================] - 11s 13ms/step - loss: 0.4727 - accuracy: 0.8040 - val_loss: 0.9179 - val_accuracy: 0.6165
# Epoch 48/100
# 835/835 [==============================] - 10s 12ms/step - loss: 0.4636 - accuracy: 0.8094 - val_loss: 0.9807 - val_accuracy: 0.5763
# Epoch 49/100
# 835/835 [==============================] - 9s 11ms/step - loss: 0.4550 - accuracy: 0.8179 - val_loss: 0.9959 - val_accuracy: 0.6081
# Epoch 50/100
# 835/835 [==============================] - 10s 12ms/step - loss: 0.4576 - accuracy: 0.8131 - val_loss: 1.0154 - val_accuracy: 0.5763
# Epoch 51/100
# 835/835 [==============================] - 10s 11ms/step - loss: 0.4474 - accuracy: 0.8264 - val_loss: 1.0317 - val_accuracy: 0.5996
# Epoch 52/100
# 835/835 [==============================] - 10s 12ms/step - loss: 0.4282 - accuracy: 0.8357 - val_loss: 0.9526 - val_accuracy: 0.5932
# Epoch 53/100
# 835/835 [==============================] - 11s 13ms/step - loss: 0.4299 - accuracy: 0.8398 - val_loss: 0.9583 - val_accuracy: 0.6123
# Epoch 54/100
# 835/835 [==============================] - 8s 10ms/step - loss: 0.4361 - accuracy: 0.8332 - val_loss: 0.9867 - val_accuracy: 0.5826
# Epoch 55/100
# 835/835 [==============================] - 9s 11ms/step - loss: 0.4188 - accuracy: 0.8380 - val_loss: 0.9772 - val_accuracy: 0.6144
# Epoch 56/100
# 835/835 [==============================] - 6s 7ms/step - loss: 0.4120 - accuracy: 0.8465 - val_loss: 0.9755 - val_accuracy: 0.6250
# Epoch 57/100
# 835/835 [==============================] - 7s 8ms/step - loss: 0.4062 - accuracy: 0.8455 - val_loss: 1.0712 - val_accuracy: 0.5720
# Epoch 58/100
# 835/835 [==============================] - 9s 11ms/step - loss: 0.3930 - accuracy: 0.8567 - val_loss: 1.0139 - val_accuracy: 0.5953
# Epoch 59/100
# 835/835 [==============================] - 9s 11ms/step - loss: 0.4015 - accuracy: 0.8524 - val_loss: 1.0817 - val_accuracy: 0.5720
# Epoch 60/100
# 835/835 [==============================] - 9s 11ms/step - loss: 0.3873 - accuracy: 0.8589 - val_loss: 1.0776 - val_accuracy: 0.6038
# Epoch 61/100
# 835/835 [==============================] - 9s 11ms/step - loss: 0.3771 - accuracy: 0.8633 - val_loss: 1.1121 - val_accuracy: 0.5826
# Epoch 62/100
# 835/835 [==============================] - 10s 12ms/step - loss: 0.3802 - accuracy: 0.8646 - val_loss: 1.1631 - val_accuracy: 0.5742
# Epoch 63/100
# 835/835 [==============================] - 9s 11ms/step - loss: 0.3656 - accuracy: 0.8691 - val_loss: 1.1108 - val_accuracy: 0.5826
# Epoch 64/100
# 835/835 [==============================] - 9s 11ms/step - loss: 0.3675 - accuracy: 0.8667 - val_loss: 1.1234 - val_accuracy: 0.5890
# Epoch 65/100
# 835/835 [==============================] - 9s 11ms/step - loss: 0.3561 - accuracy: 0.8750 - val_loss: 1.0129 - val_accuracy: 0.5869
# Epoch 66/100
# 835/835 [==============================] - 9s 11ms/step - loss: 0.3565 - accuracy: 0.8750 - val_loss: 1.0503 - val_accuracy: 0.6017
# Epoch 67/100
# 835/835 [==============================] - 9s 11ms/step - loss: 0.3481 - accuracy: 0.8780 - val_loss: 1.0713 - val_accuracy: 0.5869
# Epoch 68/100
# 835/835 [==============================] - 10s 12ms/step - loss: 0.3474 - accuracy: 0.8771 - val_loss: 1.1463 - val_accuracy: 0.6038
# Epoch 69/100
# 835/835 [==============================] - 11s 13ms/step - loss: 0.3385 - accuracy: 0.8813 - val_loss: 1.1588 - val_accuracy: 0.5911
# Epoch 70/100
# 835/835 [==============================] - 8s 9ms/step - loss: 0.3321 - accuracy: 0.8822 - val_loss: 1.1594 - val_accuracy: 0.6123
# Epoch 71/100
# 835/835 [==============================] - 6s 7ms/step - loss: 0.3391 - accuracy: 0.8850 - val_loss: 1.1205 - val_accuracy: 0.5953
# Epoch 72/100
# 835/835 [==============================] - 8s 9ms/step - loss: 0.3224 - accuracy: 0.8923 - val_loss: 1.0526 - val_accuracy: 0.6081
# Epoch 73/100
# 835/835 [==============================] - 10s 11ms/step - loss: 0.3145 - accuracy: 0.8931 - val_loss: 1.1542 - val_accuracy: 0.5932
# Epoch 74/100
# 835/835 [==============================] - 10s 11ms/step - loss: 0.3183 - accuracy: 0.8965 - val_loss: 1.1217 - val_accuracy: 0.6081
# Epoch 75/100
# 835/835 [==============================] - 9s 11ms/step - loss: 0.3236 - accuracy: 0.8922 - val_loss: 1.1427 - val_accuracy: 0.5678
# Epoch 76/100
# 835/835 [==============================] - 10s 12ms/step - loss: 0.3102 - accuracy: 0.8986 - val_loss: 1.1451 - val_accuracy: 0.5890
# Epoch 77/100
# 835/835 [==============================] - 7s 9ms/step - loss: 0.3117 - accuracy: 0.8995 - val_loss: 1.1626 - val_accuracy: 0.5847
# Epoch 78/100
# 835/835 [==============================] - 8s 9ms/step - loss: 0.3086 - accuracy: 0.9000 - val_loss: 1.2531 - val_accuracy: 0.6017
# Epoch 79/100
# 835/835 [==============================] - 9s 11ms/step - loss: 0.3105 - accuracy: 0.9003 - val_loss: 1.1300 - val_accuracy: 0.5805
# Epoch 80/100
# 835/835 [==============================] - 10s 12ms/step - loss: 0.3042 - accuracy: 0.9022 - val_loss: 1.2413 - val_accuracy: 0.5805
# Epoch 81/100
# 835/835 [==============================] - 10s 12ms/step - loss: 0.2953 - accuracy: 0.9064 - val_loss: 1.1699 - val_accuracy: 0.5869
# Epoch 82/100
# 835/835 [==============================] - 10s 12ms/step - loss: 0.2958 - accuracy: 0.9052 - val_loss: 1.3252 - val_accuracy: 0.5742
# Epoch 83/100
# 835/835 [==============================] - 7s 9ms/step - loss: 0.2922 - accuracy: 0.9064 - val_loss: 1.1500 - val_accuracy: 0.5847
# Epoch 84/100
# 835/835 [==============================] - 8s 10ms/step - loss: 0.2946 - accuracy: 0.9079 - val_loss: 1.1156 - val_accuracy: 0.5975
# Epoch 85/100
# 835/835 [==============================] - 5s 6ms/step - loss: 0.2952 - accuracy: 0.9027 - val_loss: 1.1070 - val_accuracy: 0.5953

# %%
fig, axs = plt.subplots(2, 2, figsize=(12, 10))
keys = [['loss', 'accuracy'], ['val_loss', 'val_accuracy']]
for ax_row, key_row in zip(axs, keys):
    for ax, key in zip(ax_row, key_row):
        vals = res.history[key]
        ax.plot(np.arange(len(vals)), vals)
        ax.set_title(key)

# %%
preds = res.model.predict(test[0])
ppreds = (preds > 0.3).astype(np.uint8)
np.sum(ppreds.squeeze() == test[1]) / test[1].shape[0]
# Out:
#  1/16 [>.............................] - ETA: 0s
# 16/16 [==============================] - 0s 2ms/step
# 0.5925155925155925

# %%
y_pred = res.model.predict(test[0])
fpr, tpr, thresholds = roc_curve(test[1], y_pred)
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure(figsize=(6, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'AUC = {roc_auc:.2f}')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()
# Out:
#  1/16 [>.............................] - ETA: 0s
# 16/16 [==============================] - 0s 2ms/step

# %%
display(confusion_matrix(test[1], ppreds))
print(classification_report(test[1], ppreds))
# Out:
# array([[ 65, 131],
#        [ 75, 210]])
#               precision    recall  f1-score   support
#
#            0       0.46      0.33      0.39       196
#            1       0.62      0.74      0.67       285
#
#     accuracy                           0.57       481
#    macro avg       0.54      0.53      0.53       481
# weighted avg       0.55      0.57      0.56       481
